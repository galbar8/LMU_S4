# %%
from __future__ import annotations

from src.models.v2.build_model import BlockConfig
from ptbxl_task import PTBXLTask

# %% [markdown]
# ### BCEWithLogitsLoss
#
# With standard BCEWithLogitsLoss(), the model learns to:
# Overpredict common classes (NORM) → high precision, low recall for rare classes
# Underpredict rare classes (MI, CD) → model treats them as noise
# The Solution: Weighted Loss with pos_weight
# Use BCEWithLogitsLoss(pos_weight=...) to penalize missing positive samples of rare classes more heavily.

# %%
def create_block_cfg_ctor(dropout: float, mlp_ratio: float, droppath_final: float,
                          layerscale_init: float, residual_gain: float, pool: str,
                          d_state: int, mode: str, bidirectional: bool):
    """Create a block config constructor with the given hyperparameters."""
    def block_cfg_ctor(theta: int) -> BlockConfig:
        return BlockConfig(
            kind="s4",
            d_state=d_state,
            channels=1,
            bidirectional=bidirectional,
            mode=mode,
            dt_min=0.001,
            dt_max=0.1,
            dropout=dropout,
            mlp_ratio=mlp_ratio,
            droppath_final=droppath_final,
            layerscale_init=layerscale_init,
            residual_gain=residual_gain,
            pool=pool,
        )
    return block_cfg_ctor

# %%
import torch
from pathlib import Path
from typing import Dict, Any

current_dir = Path.cwd()
project_root = current_dir.parent.parent.parent
data_root = str(project_root / "src" / "datasets" / "ptbxl" / "data")

args: Dict[str, Any] = {
        # data
        "data_root": str(data_root),
        "batch": 32,
        "data_loader_kwargs": {
            "num_workers": 0,
            "sampling": "lr100",  # 100Hz sampling rate
            "length": 1000,       # 10 seconds at 100Hz
            "leads": None,        # Use all 12 leads
            "folds_train": (1, 2, 3, 4, 5, 6, 7, 8),
            "fold_val": 9,
            "fold_test": 10,
            "pin_memory": False,  # Not needed for MPS
            "persistent_workers": False,
        },

        # training
        "epochs": 100,
        "lr": 1e-3,
        "wd": 5e-4,
        "amp": True,  # M4 MPS works well with AMP
        "save_dir": "./runs/ptbxl_s4_task",
        "warmup_epochs": 5,
        "patience": 5,
        "min_delta": 0.001,
        "threshold": 0.5,      # For multi-label classification
        "early_key": "f1_micro",  # Use F1-micro for early stopping

        # model scaffold
        "d_model": 256,
        "depth": 6,
        "dropout": 0.2,
        "mlp_ratio": 2.0,
        "droppath_final": 0.1,
        "layerscale_init": 1e-2,
        "residual_gain": 1.0,
        "pool": "mean",

        # S4-specific hyperparameters
        "pos_weight": True,
        "d_state": 64,
        "mode": "s4d",
        "bidirectional": True,
    }

args["block_cfg_ctor"] = create_block_cfg_ctor(
    dropout=args["dropout"],
    mlp_ratio=args["mlp_ratio"],
    droppath_final=args["droppath_final"],
    layerscale_init=args["layerscale_init"],
    residual_gain=args["residual_gain"],
    pool=args["pool"],
    d_state=args["d_state"],
    mode=args["mode"],
    bidirectional=args["bidirectional"],
)

# M4-optimized device selection
if torch.backends.mps.is_available():
    args["device"] = torch.device("mps")
    print("🚀 Using MPS (M4 Neural Engine)")
elif torch.cuda.is_available():
    args["device"] = torch.device("cuda")
else:
    args["device"] = torch.device("cpu")
    args["amp"] = False

# %%
import torch
import os

from src.train_utils.trainer import Trainer

def main() -> None:
    task = PTBXLTask()

    # M4-optimized MPS settings
    if torch.backends.mps.is_available():
        torch.mps.set_per_process_memory_fraction(0.9)
        os.environ["PYTORCH_MPS_HIGH_WATERMARK_RATIO"] = "0.0"

    trainer = Trainer(args=args, task=task)

    best_metric, ckpt_path = trainer.fit()
    print(f"Done. Best {trainer.early_key}={best_metric:.4f} @ {ckpt_path}")

    return trainer

# %%
main()

# %%
import matplotlib.pyplot as plt

def plot_history(history) -> None:
    # Loss plot
    plt.figure(figsize=(12, 8))
    plt.plot(history["train_loss"], label="train_loss", linewidth=2)
    plt.plot(history["val_loss"], label="val_loss", linewidth=2)
    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("Loss", fontsize=12)
    plt.legend(fontsize=11)
    plt.title("Training and Validation Loss", fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    # F1-Micro plot
    plt.figure(figsize=(12, 8))
    plt.plot(history["train_f1_micro"], label="train_f1_micro", linewidth=2)
    plt.plot(history["val_f1_micro"], label="val_f1_micro", linewidth=2)
    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("F1-Micro", fontsize=12)
    plt.legend(fontsize=11)
    plt.title("Training and Validation F1-Micro Score", fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
from src.utils.checkpoint import load_trainer_from_checkpoint

trainer = load_trainer_from_checkpoint(
    checkpoint_path="./runs/ptbxl_s4_task/best.pt",
    args=args,
    task=PTBXLTask(),
)

history = trainer.history

plot_history(history)
# Out:
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: divide by zero encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: overflow encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: invalid value encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Computing pos_weight from training set...
#   Total training samples: 17440
#   Positive samples per class: [7607. 4388. 4192. 2121. 3912.]
#   Negative samples per class: [ 9833. 13052. 13248. 15319. 13528.]
#   Class prevalence: [43.61812  25.160551 24.036697 12.161697 22.431192]%
# 📊 Computed pos_weight for imbalanced classes: [1.2926252 2.9744759 3.1603053 7.2225366 3.4580777]
# ✅ Loaded checkpoint from epoch 13
# 📊 Val metrics: {'loss': 0.7931492715136297, 'time_s': 30.87038012499943, 'f1_micro': 0.729014859637596}

# %%
from ptbxl_eval import evaluate_best_model, print_evaluation_results

# Evaluate best model
logits_val, labels_val, logits_test, labels_test = evaluate_best_model(
    args=args,
    task=PTBXLTask(),
    best_model_path="./runs/ptbxl_s4_task/best.pt",
    data_root=data_root
)

# Print results
print_evaluation_results(
    logits_val=logits_val,
    labels_val=labels_val,
    logits_test=logits_test,
    labels_test=labels_test,
    threshold=args["threshold"],
    class_names=["NORM", "MI", "STTC", "HYP", "CD"]
)
# Out:
# ============================================================
# VALIDATION SET RESULTS:
# ============================================================
# f1_micro: 0.7299
#
# ============================================================
# TEST SET RESULTS:
# ============================================================
# f1_micro: 0.7283
#
# ============================================================
# PER-CLASS F1 SCORES (Validation):
# ============================================================
# NORM    : F1=0.8418 (P=0.7625, R=0.9394, support=957)
# MI      : F1=0.7169 (P=0.6776, R=0.7610, support=544)
# STTC    : F1=0.7207 (P=0.6511, R=0.8071, support=534)
# HYP     : F1=0.4429 (P=0.3584, R=0.5793, support=271)
# CD      : F1=0.7216 (P=0.6297, R=0.8451, support=497)
#
# ============================================================
# PER-CLASS F1 SCORES (Test):
# ============================================================
# NORM    : F1=0.8376 (P=0.7444, R=0.9575, support=964)
# MI      : F1=0.7254 (P=0.6826, R=0.7740, support=553)
# STTC    : F1=0.7335 (P=0.6792, R=0.7973, support=523)
# HYP     : F1=0.4522 (P=0.3586, R=0.6122, support=263)
# CD      : F1=0.6891 (P=0.5936, R=0.8213, support=498)
# ============================================================

# %%
from src.utils.common import print_model_details

print_model_details(model=trainer.model)

# %% [markdown]
# ### Training with different fractions of the dataset

# %%
from src.train_utils.trainer import Trainer
import matplotlib.pyplot as plt
from ptbxl_task import PTBXLTask
from ptbxl_eval import evaluate_best_model, print_evaluation_results

for frac in [0.1, 0.25, 0.5]:
    print(f"\n Training with fraction: {frac}")

    if args.get("device") and args["device"].type == "mps":
        torch.mps.set_per_process_memory_fraction(0.9)
        os.environ["PYTORCH_MPS_HIGH_WATERMARK_RATIO"] = "0.0"

    args["fraction"] = frac
    args["save_dir"] = f"./runs/ptbxl_s4_task_frac_{int(frac*100)}"
    trainer = Trainer(args=args, task=PTBXLTask())
    best_metric, best_path = trainer.fit()

    print(f"\n Training complete for fraction {frac}! Best validation {trainer.early_key}: {best_metric:.4f}")
    print(f" Best model saved to: {best_path}")

    history = trainer.history

    plot_history(history)

    logits_val, labels_val, logits_test, labels_test = evaluate_best_model(
    args=args,
    task=PTBXLTask(),
    best_model_path=f"./runs/ptbxl_s4_task_frac_{int(frac*100)}/best.pt",
    data_root=data_root)

    print_evaluation_results(
    logits_val=logits_val,
    labels_val=labels_val,
    logits_test=logits_test,
    labels_test=labels_test,
    threshold=args["threshold"],
    class_names=["NORM", "MI", "STTC", "HYP", "CD"]
    )
# Out:
#  Training with fraction: 0.1
#    Applying data fraction: 10.0%
#    Original train size: 17441
#    Original val size: 2193
#    Reduced train size: 1742
#    Reduced val size: 218
#    Test size: 2203 (unchanged)
# Computing pos_weight from training set...
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: divide by zero encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: overflow encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: invalid value encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   Total training samples: 1728
#   Positive samples per class: [755. 434. 412. 197. 431.]
#   Negative samples per class: [ 973. 1294. 1316. 1531. 1297.]
#   Class prevalence: [43.69213  25.11574  23.842592 11.400463 24.94213 ]%
# 📊 Computed pos_weight for imbalanced classes: [1.2887417 2.981567  3.1941748 7.7715735 3.0092807]
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.2878
# Epoch 000/100 | train 1.0369/0.2838 | val 1.0146/0.2878 | t 77.5s/3.1s | lr 1.00e-06
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.4975
# Epoch 001/100 | train 0.9773/0.4410 | val 0.9000/0.4975 | t 72.9s/2.9s | lr 2.01e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.5920
# Epoch 002/100 | train 0.8628/0.5586 | val 0.8345/0.5920 | t 72.8s/2.9s | lr 4.01e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.5949
# Epoch 003/100 | train 0.8196/0.5818 | val 0.8082/0.5949 | t 73.8s/3.0s | lr 6.00e-04
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:209: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 004/100 | train 0.8022/0.5977 | val 0.8287/0.5359 | t 72.7s/3.0s | lr 8.00e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.6128
# Epoch 005/100 | train 0.7719/0.6157 | val 0.8015/0.6128 | t 74.2s/3.1s | lr 1.00e-03
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.6210
# Epoch 006/100 | train 0.7433/0.6233 | val 0.7912/0.6210 | t 77.5s/3.1s | lr 1.00e-03
# Epoch 007/100 | train 0.7220/0.6399 | val 0.7763/0.5932 | t 78.1s/3.2s | lr 9.99e-04
# Epoch 008/100 | train 0.7047/0.6449 | val 0.7615/0.6112 | t 78.7s/3.2s | lr 9.98e-04
# Epoch 009/100 | train 0.6764/0.6660 | val 0.7754/0.6059 | t 80.0s/3.2s | lr 9.96e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.6371
# Epoch 010/100 | train 0.6529/0.6657 | val 0.7831/0.6371 | t 80.5s/3.3s | lr 9.93e-04
# Epoch 011/100 | train 0.6291/0.6907 | val 0.8067/0.5993 | t 82.1s/3.3s | lr 9.90e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.6479
# Epoch 012/100 | train 0.6102/0.6906 | val 0.8483/0.6479 | t 82.2s/3.3s | lr 9.87e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.6581
# Epoch 013/100 | train 0.5773/0.7117 | val 0.9035/0.6581 | t 82.5s/3.3s | lr 9.83e-04
# Epoch 014/100 | train 0.5325/0.7283 | val 0.9181/0.6552 | t 83.3s/3.4s | lr 9.78e-04
# Epoch 015/100 | train 0.4853/0.7484 | val 1.0748/0.6534 | t 84.1s/3.4s | lr 9.73e-04
# Epoch 016/100 | train 0.4653/0.7634 | val 0.9739/0.6193 | t 84.5s/3.4s | lr 9.67e-04
# Epoch 017/100 | train 0.4327/0.7758 | val 1.1550/0.6290 | t 84.1s/3.4s | lr 9.61e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_10/best.pt
# ✅ new best f1_micro 0.6600
# Epoch 018/100 | train 0.3849/0.8100 | val 1.1992/0.6600 | t 88.0s/3.5s | lr 9.55e-04
# Epoch 019/100 | train 0.3539/0.8142 | val 1.1793/0.6048 | t 86.2s/3.4s | lr 9.47e-04
# Epoch 020/100 | train 0.3262/0.8367 | val 1.6237/0.6605 | t 87.0s/3.5s | lr 9.40e-04
# Epoch 021/100 | train 0.3012/0.8525 | val 1.4995/0.6473 | t 86.6s/3.5s | lr 9.32e-04
# Epoch 022/100 | train 0.2559/0.8725 | val 1.5223/0.6318 | t 90.0s/3.5s | lr 9.23e-04
# Epoch 023/100 | train 0.2217/0.8899 | val 1.9391/0.6469 | t 87.7s/3.6s | lr 9.14e-04
# ⏹ Early stopping (patience=5, best=0.6600).
# 📊 Training history saved to ./runs/ptbxl_s4_task_frac_10/history.json
#
#  Training complete for fraction 0.1! Best validation f1_micro: 0.6600
#  Best model saved to: ./runs/ptbxl_s4_task_frac_10/best.pt
# 📊 Evaluating best model on validation and test sets...
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: divide by zero encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: overflow encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: invalid value encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ✅ Loaded checkpoint from epoch 18
# 📈 Val metrics: {'loss': 1.199210519090705, 'time_s': 3.463764292000178, 'f1_micro': 0.6599757491543975}
#
# ============================================================
# VALIDATION SET RESULTS:
# ============================================================
# f1_micro: 0.6438
#
# ============================================================
# TEST SET RESULTS:
# ============================================================
# f1_micro: 0.6360
#
# ============================================================
# PER-CLASS F1 SCORES (Validation):
# ============================================================
# NORM    : F1=0.7969 (P=0.7479, R=0.8527, support=957)
# MI      : F1=0.5843 (P=0.4616, R=0.7960, support=544)
# STTC    : F1=0.6385 (P=0.5920, R=0.6929, support=534)
# HYP     : F1=0.3558 (P=0.3344, R=0.3801, support=271)
# CD      : F1=0.5872 (P=0.6362, R=0.5453, support=497)
#
# ============================================================
# PER-CLASS F1 SCORES (Test):
# ============================================================
# NORM    : F1=0.8086 (P=0.7489, R=0.8786, support=964)
# MI      : F1=0.5787 (P=0.4583, R=0.7848, support=553)
# STTC    : F1=0.6116 (P=0.5820, R=0.6444, support=523)
# HYP     : F1=0.3310 (P=0.3082, R=0.3574, support=263)
# CD      : F1=0.5541 (P=0.6009, R=0.5141, support=498)
# ============================================================
#
#  Training with fraction: 0.25
#    Applying data fraction: 25.0%
#    Original train size: 17441
#    Original val size: 2193
#    Reduced train size: 4359
#    Reduced val size: 547
#    Test size: 2203 (unchanged)
# Computing pos_weight from training set...
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: divide by zero encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: overflow encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: invalid value encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   Total training samples: 4352
#   Positive samples per class: [1899. 1095. 1060.  501.  997.]
#   Negative samples per class: [2453. 3257. 3292. 3851. 3355.]
#   Class prevalence: [43.63511  25.160847 24.356617 11.511949 22.909008]%
# 📊 Computed pos_weight for imbalanced classes: [1.2917325 2.9744291 3.1056604 7.686627  3.3650954]
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.4691
# Epoch 000/100 | train 1.0283/0.4530 | val 1.0294/0.4691 | t 222.7s/9.7s | lr 1.00e-06
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.5852
# Epoch 001/100 | train 0.8976/0.5449 | val 0.8427/0.5852 | t 226.3s/9.3s | lr 2.01e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.5942
# Epoch 002/100 | train 0.8062/0.6026 | val 0.8202/0.5942 | t 223.6s/9.0s | lr 4.01e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.6513
# Epoch 003/100 | train 0.7794/0.6130 | val 0.7927/0.6513 | t 220.9s/8.7s | lr 6.00e-04
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:209: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 004/100 | train 0.7494/0.6235 | val 0.7575/0.6486 | t 220.0s/8.8s | lr 8.00e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.6598
# Epoch 005/100 | train 0.7178/0.6370 | val 0.8101/0.6598 | t 219.6s/8.8s | lr 1.00e-03
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.6677
# Epoch 006/100 | train 0.6782/0.6566 | val 0.7868/0.6677 | t 220.7s/8.7s | lr 1.00e-03
# Epoch 007/100 | train 0.6607/0.6721 | val 0.7799/0.6488 | t 218.4s/8.7s | lr 9.99e-04
# Epoch 008/100 | train 0.6239/0.6836 | val 0.8725/0.6648 | t 222.4s/10.9s | lr 9.98e-04
# Epoch 009/100 | train 0.6031/0.6990 | val 0.8205/0.6603 | t 280.7s/10.9s | lr 9.96e-04
# Epoch 010/100 | train 0.5644/0.7211 | val 0.8371/0.6534 | t 280.3s/11.0s | lr 9.93e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.6787
# Epoch 011/100 | train 0.5421/0.7262 | val 0.8709/0.6787 | t 277.1s/11.2s | lr 9.90e-04
# Epoch 012/100 | train 0.5008/0.7486 | val 1.0003/0.6698 | t 259.2s/7.6s | lr 9.87e-04
# Epoch 013/100 | train 0.4707/0.7672 | val 0.8714/0.6551 | t 202.8s/8.7s | lr 9.83e-04
# Epoch 014/100 | train 0.4337/0.7823 | val 1.1166/0.6533 | t 217.2s/8.9s | lr 9.78e-04
# Epoch 015/100 | train 0.3999/0.8058 | val 1.1764/0.6702 | t 220.2s/8.9s | lr 9.73e-04
# Epoch 016/100 | train 0.3638/0.8209 | val 1.1983/0.6666 | t 221.2s/8.8s | lr 9.67e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.6859
# Epoch 017/100 | train 0.3187/0.8433 | val 1.6282/0.6859 | t 222.5s/8.8s | lr 9.61e-04
# Epoch 018/100 | train 0.3018/0.8520 | val 1.5103/0.6654 | t 221.4s/9.0s | lr 9.55e-04
# Epoch 019/100 | train 0.2773/0.8638 | val 1.5056/0.6488 | t 223.9s/8.9s | lr 9.47e-04
# Epoch 020/100 | train 0.2456/0.8784 | val 1.7022/0.6661 | t 224.9s/9.1s | lr 9.40e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_25/best.pt
# ✅ new best f1_micro 0.6893
# Epoch 021/100 | train 0.2228/0.8893 | val 1.7634/0.6893 | t 228.1s/9.2s | lr 9.32e-04
# Epoch 022/100 | train 0.2097/0.8984 | val 2.6455/0.6712 | t 197.6s/8.2s | lr 9.23e-04
# Epoch 023/100 | train 0.1873/0.9070 | val 2.6463/0.6670 | t 223.1s/9.0s | lr 9.14e-04
# Epoch 024/100 | train 0.1624/0.9240 | val 2.7260/0.6749 | t 228.8s/10.1s | lr 9.05e-04
# Epoch 025/100 | train 0.1648/0.9225 | val 2.4627/0.6449 | t 236.3s/10.1s | lr 8.95e-04
# Epoch 026/100 | train 0.1417/0.9334 | val 2.8878/0.6630 | t 235.7s/9.3s | lr 8.84e-04
# ⏹ Early stopping (patience=5, best=0.6893).
# 📊 Training history saved to ./runs/ptbxl_s4_task_frac_25/history.json
#
#  Training complete for fraction 0.25! Best validation f1_micro: 0.6893
#  Best model saved to: ./runs/ptbxl_s4_task_frac_25/best.pt
# 📊 Evaluating best model on validation and test sets...
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: divide by zero encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: overflow encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: invalid value encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ✅ Loaded checkpoint from epoch 21
# 📈 Val metrics: {'loss': 1.763405718685722, 'time_s': 9.174499374999868, 'f1_micro': 0.689316531196989}
#
# ============================================================
# VALIDATION SET RESULTS:
# ============================================================
# f1_micro: 0.6873
#
# ============================================================
# TEST SET RESULTS:
# ============================================================
# f1_micro: 0.6799
#
# ============================================================
# PER-CLASS F1 SCORES (Validation):
# ============================================================
# NORM    : F1=0.8132 (P=0.7427, R=0.8986, support=957)
# MI      : F1=0.6246 (P=0.5973, R=0.6544, support=544)
# STTC    : F1=0.6807 (P=0.6000, R=0.7865, support=534)
# HYP     : F1=0.3957 (P=0.3828, R=0.4096, support=271)
# CD      : F1=0.6640 (P=0.6660, R=0.6620, support=497)
#
# ============================================================
# PER-CLASS F1 SCORES (Test):
# ============================================================
# NORM    : F1=0.8076 (P=0.7329, R=0.8994, support=964)
# MI      : F1=0.6162 (P=0.5878, R=0.6474, support=553)
# STTC    : F1=0.6898 (P=0.6067, R=0.7992, support=523)
# HYP     : F1=0.4007 (P=0.3879, R=0.4144, support=263)
# CD      : F1=0.6194 (P=0.6163, R=0.6225, support=498)
# ============================================================
#
#  Training with fraction: 0.5
#    Applying data fraction: 50.0%
#    Original train size: 17441
#    Original val size: 2193
#    Reduced train size: 8719
#    Reduced val size: 1096
#    Test size: 2203 (unchanged)
# Computing pos_weight from training set...
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: divide by zero encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: overflow encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: invalid value encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   Total training samples: 8704
#   Positive samples per class: [3800. 2191. 2132. 1039. 1979.]
#   Negative samples per class: [4904. 6513. 6572. 7665. 6725.]
#   Class prevalence: [43.65809  25.172335 24.494486 11.93704  22.736673]%
# 📊 Computed pos_weight for imbalanced classes: [1.2905263 2.9726152 3.0825515 7.377286  3.398181 ]
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.3545
# Epoch 000/100 | train 1.0516/0.3571 | val 1.0461/0.3545 | t 446.2s/18.2s | lr 1.00e-06
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.6124
# Epoch 001/100 | train 0.8615/0.5595 | val 0.8406/0.6124 | t 442.8s/17.8s | lr 2.01e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.6215
# Epoch 002/100 | train 0.7757/0.6125 | val 0.7710/0.6215 | t 444.8s/18.0s | lr 4.01e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.6266
# Epoch 003/100 | train 0.7366/0.6348 | val 0.7484/0.6266 | t 460.3s/18.8s | lr 6.00e-04
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:209: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.6631
# Epoch 004/100 | train 0.7056/0.6509 | val 0.7261/0.6631 | t 468.8s/18.6s | lr 8.00e-04
# Epoch 005/100 | train 0.6807/0.6642 | val 0.7123/0.6454 | t 472.1s/18.4s | lr 1.00e-03
# Epoch 006/100 | train 0.6441/0.6778 | val 0.7557/0.6511 | t 470.4s/18.7s | lr 1.00e-03
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.6771
# Epoch 007/100 | train 0.6118/0.6972 | val 0.7927/0.6771 | t 477.6s/19.3s | lr 9.99e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.6880
# Epoch 008/100 | train 0.5897/0.7092 | val 0.7809/0.6880 | t 483.8s/19.1s | lr 9.98e-04
# 💾 saved best model to ./runs/ptbxl_s4_task_frac_50/best.pt
# ✅ new best f1_micro 0.7119
# Epoch 009/100 | train 0.5539/0.7252 | val 0.6806/0.7119 | t 488.2s/19.9s | lr 9.96e-04
# Epoch 010/100 | train 0.5206/0.7448 | val 0.7171/0.6820 | t 496.2s/19.2s | lr 9.93e-04
# Epoch 011/100 | train 0.5011/0.7561 | val 0.7304/0.6834 | t 476.4s/19.3s | lr 9.90e-04
# Epoch 012/100 | train 0.4740/0.7685 | val 0.7469/0.7017 | t 475.2s/19.1s | lr 9.87e-04
# Epoch 013/100 | train 0.4372/0.7877 | val 1.1773/0.6862 | t 480.2s/19.2s | lr 9.83e-04
# Epoch 014/100 | train 0.4150/0.7993 | val 0.9378/0.6933 | t 481.4s/18.9s | lr 9.78e-04
# ⏹ Early stopping (patience=5, best=0.7119).
# 📊 Training history saved to ./runs/ptbxl_s4_task_frac_50/history.json
#
#  Training complete for fraction 0.5! Best validation f1_micro: 0.7119
#  Best model saved to: ./runs/ptbxl_s4_task_frac_50/best.pt
# 📊 Evaluating best model on validation and test sets...
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: divide by zero encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: overflow encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/src/models/s4/s4_block.py:322: RuntimeWarning: invalid value encountered in matmul
#   A = T @ M @ np.linalg.inv(T)
# /Users/glbrlb/PycharmProjects/Msc/LMU_S4/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ✅ Loaded checkpoint from epoch 9
# 📈 Val metrics: {'loss': 0.6806275183266967, 'time_s': 19.916280125000412, 'f1_micro': 0.7118968520502283}
#
# ============================================================
# VALIDATION SET RESULTS:
# ============================================================
# f1_micro: 0.7094
#
# ============================================================
# TEST SET RESULTS:
# ============================================================
# f1_micro: 0.7012
#
# ============================================================
# PER-CLASS F1 SCORES (Validation):
# ============================================================
# NORM    : F1=0.8453 (P=0.7907, R=0.9080, support=957)
# MI      : F1=0.6829 (P=0.6110, R=0.7739, support=544)
# STTC    : F1=0.7309 (P=0.6812, R=0.7884, support=534)
# HYP     : F1=0.4175 (P=0.3312, R=0.5646, support=271)
# CD      : F1=0.6629 (P=0.5550, R=0.8229, support=497)
#
# ============================================================
# PER-CLASS F1 SCORES (Test):
# ============================================================
# NORM    : F1=0.8187 (P=0.7564, R=0.8921, support=964)
# MI      : F1=0.6710 (P=0.6091, R=0.7468, support=553)
# STTC    : F1=0.7363 (P=0.6956, R=0.7820, support=523)
# HYP     : F1=0.4356 (P=0.3405, R=0.6046, support=263)
# CD      : F1=0.6562 (P=0.5557, R=0.8012, support=498)
# ============================================================
